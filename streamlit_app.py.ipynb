# %%
# !pip install streamlit==1.42.0
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def load_data(uploaded_file):
    if uploaded_file is not None:
        df = pd.read_csv(uploaded_file)
        return df
    return None

st.title("Crop Yield Analysis")

uploaded_file = st.file_uploader("Upload CSV file", type=["csv"])

df = load_data(uploaded_file)
if df is not None:
    st.write("### Dataset Preview")
    st.write(df.head())
    
    if 'Unnamed: 0' in df.columns:
        df.drop(columns=['Unnamed: 0'], inplace=True)
    
    st.write("### Summary Statistics")
    st.write(df.describe())
    
    st.write("### Data Visualization")
    st.write("#### Correlation Heatmap")
    fig, ax = plt.subplots()
    sns.heatmap(df.corr(), annot=True, cmap='coolwarm', ax=ax)
    st.pyplot(fig)
else:
    st.warning("Please upload a CSV file to proceed.")
# Out:
# 2025-02-17 15:20:17.751 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-17 15:20:17.954
# ...
#   command:
#
#     streamlit run /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-17 15:20:17.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-17 15:20:17.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-17 15:20:17.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-17 15:20:17.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-17 15:20:17.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# The error occurs because the code provided is invalid for execution in a notebook cell. 
# The 'streamlit run' command is intended to be executed in terminal, not inside a Python script or a notebook. 
# To execute the Streamlit app properly, you should use the following instruction in your development workflow:

"""
# Open a terminal or command prompt and run the following command:
streamlit run /path/to/your_script.py
"""

# Since I cannot execute terminal commands directly, I will rewrite the recommendation for fixing this issue in the notebook comments.
# Out:
# '\n# Open a terminal or command prompt and run the following command:\nstreamlit run /path/to/your_script.py\n'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=21f5b5e6-8125-40b6-97db-a04797639fe8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
